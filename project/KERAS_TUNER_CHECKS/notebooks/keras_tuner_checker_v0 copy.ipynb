# %%
from tensorflow import keras
from tensorflow.keras import layers
import kerastuner
from kerastuner.tuners import RandomSearch

# %% [markdown]
# ### Test on IRIS dataset

# %%
from sklearn.datasets import load_iris
from tensorflow.keras.utils import to_categorical
from sklearn.model_selection import train_test_split

iris_ds = load_iris()
X = iris_ds.data
X[:5]
# Out:
# array([[5.1, 3.5, 1.4, 0.2],
#        [4.9, 3. , 1.4, 0.2],
#        [4.7, 3.2, 1.3, 0.2],
#        [4.6, 3.1, 1.5, 0.2],
#        [5. , 3.6, 1.4, 0.2]])

# %%
# convert integers to dummy variables (i.e. one hot encoded)
y_one_hot_encoded = to_categorical(iris_ds.target)
y_one_hot_encoded[:3]
# Out:
# array([[1., 0., 0.],
#        [1., 0., 0.],
#        [1., 0., 0.]], dtype=float32)

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y_one_hot_encoded, test_size=0.33, random_state=42)

# %% [markdown]
# Usage: the basics
# Here's how to perform hyperparameter tuning for a single-layer dense neural network using random search.
#
# First, we define a model-building function. It takes an argument hp from which you can sample hyperparameters, such as hp.Int('units', min_value=32, max_value=512, step=32) (an integer from a certain range).
#
# This function returns a compiled model.

# %%
def build_model(hp):
    model = keras.Sequential()
    model.add(layers.Dense(input_dim=X.shape[1],
                            units=hp.Int('units',
                                        min_value=32,
                                        max_value=512,
                                        step=32),
                            
                           activation='relu'))
    model.add(layers.Dense(3, activation='softmax'))
    model.compile(
        optimizer=keras.optimizers.Adam(
            hp.Choice('learning_rate',
                      values=[1e-2, 1e-3, 1e-4])),
        loss='categorical_crossentropy',
        metrics=['accuracy'])
    return model

# %% [markdown]
# Next, instantiate a tuner. You should specify the model-building function, the name of the objective to optimize (whether to minimize or maximize is automatically inferred for built-in metrics), the total number of trials (max_trials) to test, and the number of models that should be built and fit for each trial (executions_per_trial).
#
# Available tuners are RandomSearch and Hyperband.
#
# Note: the purpose of having multiple executions per trial is to reduce results variance and therefore be able to more accurately assess the performance of a model. If you want to get results faster, you could set executions_per_trial=1 (single round of training for each model configuration).

# %%
import os

tuner = RandomSearch(
    build_model,
    objective='val_accuracy',
    max_trials=5,
    executions_per_trial=3,
    directory=os.path.normpath('/Users/germancabrera/Documents/GitRepos/DeepLearning_concepts_checks/project/KERAS_TUNER_CHECKS'),
    project_name='iris_data_keras_tuner_test_mac')

# %% [markdown]
# summary of the search space:

# %%
tuner.search_space_summary()
# Out:
# <span style="color:#4527A0"><h1 style="font-size:18px">Search space summary</h1></span>
# <span style="color:cyan"> |-Default search space size: 2</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">units (Int)</h2></span>
# <span style="color:cyan"> |-default: None</span>
# <span style="color:blue"> |-max_value: 512</span>
# <span style="color:cyan"> |-min_value: 32</span>
# <span style="color:blue"> |-sampling: None</span>
# <span style="color:cyan"> |-step: 32</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">learning_rate (Choice)</h2></span>
# <span style="color:cyan"> |-default: 0.01</span>
# <span style="color:blue"> |-ordered: True</span>
# <span style="color:cyan"> |-values: [0.01, 0.001, 0.0001]</span>

# %% [markdown]
# Start the search for the best hyperparameter configuration. The call to search has the same signature as model.fit().
# Here's what happens in search: models are built iteratively by calling the model-building function, which populates the hyperparameter space (search space) tracked by the hp object. The tuner progressively explores the space, recording metrics for each configuration.

# %%
tuner.search(X_train, y_train,
             epochs=5,
             validation_data=(X_test, y_test)
             #validation_split=0.2,verbose=1)
             )
# Out:
# INFO:tensorflow:Oracle triggered exit

# %%
tuner.results_summary()
# Out:
# <span style="color:#4527A0"><h1 style="font-size:18px">Results summary</h1></span>
# <span style="color:cyan"> |-Results in C:\iris_data_keras_tuner_test</span>
# <span style="color:cyan"> |-Showing 10 best trials</span>
# <span style="color:cyan"> |-Objective(name='val_accuracy', direction='max')</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:cyan"> |-Trial ID: 0be236b34e35aa9297ef9b21926ebc92</span>
# <span style="color:cyan"> |-Score: 0.9000000357627869</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hyperparameters:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.01</span>
# <span style="color:blue"> |-units: 192</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:cyan"> |-Trial ID: 30648fff1de79308539d5b924a9590df</span>
# <span style="color:cyan"> |-Score: 0.59333336353302</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hyperparameters:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.001</span>
# <span style="color:blue"> |-units: 128</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:cyan"> |-Trial ID: df71ec6e95f82335310c5bc071bfddc4</span>
# <span style="color:cyan"> |-Score: 0.5533333420753479</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hyperparameters:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.001</span>
# <span style="color:blue"> |-units: 64</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:cyan"> |-Trial ID: b52205397dd1784e346b752c01311ce7</span>
# <span style="color:cyan"> |-Score: 0.3733333349227905</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hyperparameters:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.0001</span>
# <span style="color:blue"> |-units: 480</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:cyan"> |-Trial ID: d204f2ba5dfed69524d1ea5cee3fbc91</span>
# <span style="color:cyan"> |-Score: 0.13333334028720856</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hyperparameters:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.0001</span>
# <span style="color:blue"> |-units: 256</span>

# %% [markdown]
# ## Best models achieved with the hyperparametrization

# %%
models = tuner.get_best_models(num_models=2)

# %% [markdown]
# ## Evaluation score:

# %%
print('single prediction on a test instance: {}'.format(models[0].predict(X_test[-1].reshape(1, -1))))
# Out:
# single prediction on a test instance: [[1.1654331e-04 3.6200428e-01 6.3787913e-01]]

# %% [markdown]
# ## Predictions on the test set:

# %%
test_set_predictions = models[0].predict(X_test)

# %% [markdown]
# ### Esperamos obtener un score = 0.90 para el best_model_0 según el 'Results summary'

# %%
import tensorflow

categ_acc_test_set = tensorflow.keras.metrics.CategoricalAccuracy()

#best_model_0_eval_set_acc = tensorflow.keras.metrics.CategoricalAccuracy(y_test.reshape(-1,3), test_set_predictions.reshape(-1,3))
_ = categ_acc_test_set.update_state(y_test, test_set_predictions)
print('best_model_0_eval_set_acc: {}'.format(categ_acc_test_set.result().numpy()))
# Out:
# best_model_0_eval_set_acc: 0.9800000190734863

# %% [markdown]
# ## Y con precision-recall metrics?

# %%
from tensorflow.keras import metrics

def build_model(hp):
    model = keras.Sequential()
    model.add(layers.Dense(input_dim=X.shape[1],
                            units=hp.Int('units',
                                        min_value=32,
                                        max_value=512,
                                        step=32),
                            
                           activation='relu'))
    model.add(layers.Dense(3, activation='softmax'))
    model.compile(
        optimizer=keras.optimizers.Adam(
            hp.Choice('learning_rate',
                      values=[1e-2, 1e-3, 1e-4])),
        loss='categorical_crossentropy',
        metrics=[metrics.Recall()]) #, metrics.Recall()])
    return model

# %% [markdown]
# Probamos varios thresholds para el Recall

# %%
model = keras.Sequential()
model.add(layers.Dense(input_dim=X.shape[1],
                        units=384,
                        activation='relu'))
model.add(layers.Dense(3, activation='softmax'))
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=1e-2),
    loss='categorical_crossentropy',
    metrics=[metrics.Recall()])

model.fit(X_train, y_train,
             epochs=10,
             validation_data=(X_test, y_test))
# Out:
# Train on 100 samples, validate on 50 samples
# Epoch 1/10
#  32/100 [========>.....................] - ETA: 1s - loss: 1.1316 - recall_2: 0.0000e+100/100 [==============================] - 1s 8ms/sample - loss: 1.1016 - recall_2: 0.3900 - val_loss: 0.7522 - val_recall_2: 0.6800
# Epoch 2/10
#  32/100 [========>.....................] - ETA: 0s - loss: 0.7882 - recall_2: 0.59100/100 [==============================] - 0s 610us/sample - loss: 0.6370 - recall_2: 0.6200 - val_loss: 0.5010 - val_recall_2: 0.7000
# Epoch 3/10
#  32/100 [========>.....................] - ETA: 0s - loss: 0.4806 - recall_2: 0.71100/100 [==============================] - 0s 610us/sample - loss: 0.5060 - recall_2: 0.6600 - val_loss: 0.5144 - val_recall_2: 0.6800
# Epoch 4/10
#  32/100 [========>.....................] - ETA: 0s - loss: 0.5148 - recall_2: 0.68100/100 [==============================] - 0s 583us/sample - loss: 0.4868 - recall_2: 0.7300 - val_loss: 0.4401 - val_recall_2: 0.7000
# Epoch 5/10
#  32/100 [========>.....................] - ETA: 0s - loss: 0.5299 - recall_2: 0.62100/100 [==============================] - 0s 615us/sample - loss: 0.4985 - recall_2: 0.6600 - val_loss: 0.2955 - val_recall_2: 0.8600
# Epoch 6/10
#  32/100 [========>.....................] - ETA: 0s - loss: 0.3101 - recall_2: 0.90100/100 [==============================] - 0s 603us/sample - loss: 0.4471 - recall_2: 0.7300 - val_loss: 0.2323 - val_recall_2: 1.0000
# Epoch 7/10
#  32/100 [========>.....................] - ETA: 0s - loss: 0.2648 - recall_2: 0.96100/100 [==============================] - 0s 543us/sample - loss: 0.3013 - recall_2: 0.8600 - val_loss: 0.2914 - val_recall_2: 0.8200
# Epoch 8/10
#  32/100 [========>.....................] - ETA: 0s - loss: 0.2209 - recall_2: 0.90100/100 [==============================] - 0s 571us/sample - loss: 0.3155 - recall_2: 0.8300 - val_loss: 0.2620 - val_recall_2: 0.8800
# Epoch 9/10
#  32/100 [========>.....................] - ETA: 0s - loss: 0.2846 - recall_2: 0.87100/100 [==============================] - 0s 545us/sample - loss: 0.2610 - recall_2: 0.9200 - val_loss: 0.1765 - val_recall_2: 0.9800
# Epoch 10/10
#  32/100 [========>.....................] - ETA: 0s - loss: 0.2382 - recall_2: 0.93100/100 [==============================] - 0s 565us/sample - loss: 0.2217 - recall_2: 0.9300 - val_loss: 0.1502 - val_recall_2: 1.0000

# %%
model = keras.Sequential()
model.add(layers.Dense(input_dim=X.shape[1],
                        units=384,
                        activation='relu'))
model.add(layers.Dense(3, activation='softmax'))
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=1e-2),
    loss='categorical_crossentropy',
    metrics=[metrics.Recall()])

model.fit(X_train, y_train,
             epochs=10,
             validation_data=(X_test, y_test))
# Out:
# Train on 100 samples, validate on 50 samples
# Epoch 1/10
#  32/100 [========>.....................] - ETA: 1s - loss: 1.1611 - recall_3: 0.34100/100 [==============================] - 1s 10ms/sample - loss: 1.1956 - recall_3: 0.3500 - val_loss: 0.7901 - val_recall_3: 0.3400
# Epoch 2/10
#  32/100 [========>.....................] - ETA: 0s - loss: 0.8534 - recall_3: 0.25100/100 [==============================] - 0s 523us/sample - loss: 0.8329 - recall_3: 0.3400 - val_loss: 0.6740 - val_recall_3: 0.6800
# Epoch 3/10
#  32/100 [========>.....................] - ETA: 0s - loss: 0.6697 - recall_3: 0.71100/100 [==============================] - 0s 532us/sample - loss: 0.6394 - recall_3: 0.6500 - val_loss: 0.4614 - val_recall_3: 0.7000
# Epoch 4/10
#  32/100 [========>.....................] - ETA: 0s - loss: 0.4739 - recall_3: 0.68100/100 [==============================] - 0s 531us/sample - loss: 0.5434 - recall_3: 0.6500 - val_loss: 0.3757 - val_recall_3: 0.7000
# Epoch 5/10
#  32/100 [========>.....................] - ETA: 0s - loss: 0.4420 - recall_3: 0.56100/100 [==============================] - 0s 571us/sample - loss: 0.4833 - recall_3: 0.6300 - val_loss: 0.3608 - val_recall_3: 0.8400
# Epoch 6/10
#  32/100 [========>.....................] - ETA: 0s - loss: 0.3254 - recall_3: 0.93100/100 [==============================] - 0s 509us/sample - loss: 0.3722 - recall_3: 0.9100 - val_loss: 0.3031 - val_recall_3: 0.8600
# Epoch 7/10
#  32/100 [========>.....................] - ETA: 0s - loss: 0.3108 - recall_3: 0.81100/100 [==============================] - 0s 530us/sample - loss: 0.3235 - recall_3: 0.9100 - val_loss: 0.3424 - val_recall_3: 0.7800
# Epoch 8/10
#  32/100 [========>.....................] - ETA: 0s - loss: 0.3144 - recall_3: 0.75100/100 [==============================] - 0s 543us/sample - loss: 0.3611 - recall_3: 0.7500 - val_loss: 0.2717 - val_recall_3: 0.8200
# Epoch 9/10
#  32/100 [========>.....................] - ETA: 0s - loss: 0.2736 - recall_3: 0.84100/100 [==============================] - 0s 505us/sample - loss: 0.4249 - recall_3: 0.6900 - val_loss: 0.2088 - val_recall_3: 0.9800
# Epoch 10/10
#  32/100 [========>.....................] - ETA: 0s - loss: 0.2843 - recall_3: 0.96100/100 [==============================] - 0s 544us/sample - loss: 0.3878 - recall_3: 0.8000 - val_loss: 0.3984 - val_recall_3: 0.7400

# %% [markdown]
# ### Vamos teniendo val_recall_2, val_recall_3... a medida que reentrenamos (good point)

# %% [markdown]
# y si pruebo a exigir un mayor threshold? Espero obtener menor recall en estos training con un  thres. tan alto

# %%
model = keras.Sequential()
model.add(layers.Dense(input_dim=X.shape[1],
                        units=384,
                        activation='relu'))
model.add(layers.Dense(3, activation='softmax'))
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=1e-2),
    loss='categorical_crossentropy',
    metrics=[metrics.Recall(thresholds=0.85)])

model.fit(X_train, y_train, epochs=10, validation_data=(X_test, y_test))
# Out:
# Train on 100 samples, validate on 50 samples
# Epoch 1/10
#  32/100 [========>.....................] - ETA: 1s - loss: 1.1889 - recall_14: 0.0000e+0100/100 [==============================] - 1s 8ms/sample - loss: 1.2856 - recall_14: 0.1000 - val_loss: 0.9873 - val_recall_14: 0.0000e+00
# Epoch 2/10
#  32/100 [========>.....................] - ETA: 0s - loss: 1.1542 - recall_14: 0.0000e+0100/100 [==============================] - 0s 630us/sample - loss: 0.9358 - recall_14: 0.2200 - val_loss: 0.5360 - val_recall_14: 0.0800
# Epoch 3/10
#  32/100 [========>.....................] - ETA: 0s - loss: 0.5156 - recall_14: 0.031100/100 [==============================] - 0s 587us/sample - loss: 0.5898 - recall_14: 0.0100 - val_loss: 0.5811 - val_recall_14: 0.0000e+00
# Epoch 4/10
#  32/100 [========>.....................] - ETA: 0s - loss: 0.5769 - recall_14: 0.0000e+0100/100 [==============================] - 0s 694us/sample - loss: 0.5902 - recall_14: 0.0600 - val_loss: 0.3885 - val_recall_14: 0.3800
# Epoch 5/10
#  32/100 [========>.....................] - ETA: 0s - loss: 0.4203 - recall_14: 0.281100/100 [==============================] - 0s 555us/sample - loss: 0.5167 - recall_14: 0.4200 - val_loss: 0.3461 - val_recall_14: 0.3800
# Epoch 6/10
#  32/100 [========>.....................] - ETA: 0s - loss: 0.3946 - recall_14: 0.312100/100 [==============================] - 0s 547us/sample - loss: 0.4694 - recall_14: 0.3200 - val_loss: 0.4232 - val_recall_14: 0.3800
# Epoch 7/10
#  32/100 [========>.....................] - ETA: 0s - loss: 0.4721 - recall_14: 0.312100/100 [==============================] - 0s 561us/sample - loss: 0.4012 - recall_14: 0.3100 - val_loss: 0.3213 - val_recall_14: 0.5600
# Epoch 8/10
#  32/100 [========>.....................] - ETA: 0s - loss: 0.3334 - recall_14: 0.562100/100 [==============================] - 0s 527us/sample - loss: 0.3376 - recall_14: 0.4000 - val_loss: 0.2883 - val_recall_14: 0.4000
# Epoch 9/10
#  32/100 [========>.....................] - ETA: 0s - loss: 0.3359 - recall_14: 0.281100/100 [==============================] - 0s 583us/sample - loss: 0.3179 - recall_14: 0.3400 - val_loss: 0.2271 - val_recall_14: 0.4000
# Epoch 10/10
#  32/100 [========>.....................] - ETA: 0s - loss: 0.2124 - recall_14: 0.406100/100 [==============================] - 0s 638us/sample - loss: 0.2710 - recall_14: 0.3900 - val_loss: 0.2018 - val_recall_14: 0.5000

# %% [markdown]
# As expected: menores recalls

# %% [markdown]
# Y con varios thresholds lo muestra?

# %%
model = keras.Sequential()
model.add(layers.Dense(input_dim=X.shape[1],
                        units=384,
                        activation='relu'))
model.add(layers.Dense(3, activation='softmax'))
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=1e-2),
    loss='categorical_crossentropy',
    metrics=[metrics.Recall(thresholds=[0.9, 0.6])])

model.fit(X_train, y_train, epochs=10, validation_data=(X_test, y_test))
# Out:
# Train on 100 samples, validate on 50 samples
# Epoch 1/10
#  32/100 [========>.....................] - ETA: 1s - loss: 1.3017 - recall_20: 0.218100/100 [==============================] - 1s 8ms/sample - loss: 1.1112 - recall_20: 0.1800 - val_loss: 0.8818 - val_recall_20: 0.1500
# Epoch 2/10
#  32/100 [========>.....................] - ETA: 0s - loss: 0.8655 - recall_20: 0.171100/100 [==============================] - 0s 561us/sample - loss: 0.7657 - recall_20: 0.1750 - val_loss: 0.5856 - val_recall_20: 0.5400
# Epoch 3/10
#  32/100 [========>.....................] - ETA: 0s - loss: 0.6290 - recall_20: 0.531100/100 [==============================] - 0s 516us/sample - loss: 0.6277 - recall_20: 0.4800 - val_loss: 0.4184 - val_recall_20: 0.5000
# Epoch 4/10
#  32/100 [========>.....................] - ETA: 0s - loss: 0.4910 - recall_20: 0.343100/100 [==============================] - 0s 527us/sample - loss: 0.5318 - recall_20: 0.3850 - val_loss: 0.3602 - val_recall_20: 0.4700
# Epoch 5/10
#  32/100 [========>.....................] - ETA: 0s - loss: 0.3889 - recall_20: 0.375100/100 [==============================] - 0s 557us/sample - loss: 0.3965 - recall_20: 0.4200 - val_loss: 0.3413 - val_recall_20: 0.5500
# Epoch 6/10
#  32/100 [========>.....................] - ETA: 0s - loss: 0.4939 - recall_20: 0.343100/100 [==============================] - 0s 535us/sample - loss: 0.3557 - recall_20: 0.4950 - val_loss: 0.3829 - val_recall_20: 0.5400
# Epoch 7/10
#  32/100 [========>.....................] - ETA: 0s - loss: 0.3743 - recall_20: 0.500100/100 [==============================] - 0s 515us/sample - loss: 0.3965 - recall_20: 0.4950 - val_loss: 0.2873 - val_recall_20: 0.6100
# Epoch 8/10
#  32/100 [========>.....................] - ETA: 0s - loss: 0.3528 - recall_20: 0.531100/100 [==============================] - 0s 546us/sample - loss: 0.4312 - recall_20: 0.6300 - val_loss: 0.2356 - val_recall_20: 0.6600
# Epoch 9/10
#  32/100 [========>.....................] - ETA: 0s - loss: 0.2833 - recall_20: 0.593100/100 [==============================] - 0s 619us/sample - loss: 0.3327 - recall_20: 0.5950 - val_loss: 0.2742 - val_recall_20: 0.6100
# Epoch 10/10
#  32/100 [========>.....................] - ETA: 0s - loss: 0.3324 - recall_20: 0.453100/100 [==============================] - 0s 647us/sample - loss: 0.2850 - recall_20: 0.5700 - val_loss: 0.3780 - val_recall_20: 0.7000

# %%
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=1e-2),
    loss='categorical_crossentropy',
    metrics=[metrics.Recall(thresholds=[0.6, 0.9])])

model.fit(X_train, y_train, epochs=10, validation_data=(X_test, y_test))
# Out:
# Train on 100 samples, validate on 50 samples
# Epoch 1/10
#  32/100 [========>.....................] - ETA: 1s - loss: 0.4343 - recall_21: 0.656100/100 [==============================] - 1s 8ms/sample - loss: 0.3962 - recall_21: 0.6300 - val_loss: 0.2584 - val_recall_21: 0.7000
# Epoch 2/10
#  32/100 [========>.....................] - ETA: 0s - loss: 0.2717 - recall_21: 0.750100/100 [==============================] - 0s 488us/sample - loss: 0.3330 - recall_21: 0.6550 - val_loss: 0.2479 - val_recall_21: 0.7200
# Epoch 3/10
#  32/100 [========>.....................] - ETA: 0s - loss: 0.2848 - recall_21: 0.562100/100 [==============================] - 0s 552us/sample - loss: 0.2661 - recall_21: 0.6400 - val_loss: 0.1488 - val_recall_21: 0.7600
# Epoch 4/10
#  32/100 [========>.....................] - ETA: 0s - loss: 0.1474 - recall_21: 0.687100/100 [==============================] - 0s 521us/sample - loss: 0.1893 - recall_21: 0.7000 - val_loss: 0.1479 - val_recall_21: 0.7500
# Epoch 5/10
#  32/100 [========>.....................] - ETA: 0s - loss: 0.1681 - recall_21: 0.718100/100 [==============================] - 0s 589us/sample - loss: 0.1930 - recall_21: 0.7100 - val_loss: 0.1859 - val_recall_21: 0.7600
# Epoch 6/10
#  32/100 [========>.....................] - ETA: 0s - loss: 0.1110 - recall_21: 0.843100/100 [==============================] - 0s 525us/sample - loss: 0.1561 - recall_21: 0.7550 - val_loss: 0.1166 - val_recall_21: 0.8300
# Epoch 7/10
#  32/100 [========>.....................] - ETA: 0s - loss: 0.1264 - recall_21: 0.781100/100 [==============================] - 0s 537us/sample - loss: 0.1421 - recall_21: 0.7950 - val_loss: 0.1775 - val_recall_21: 0.8000
# Epoch 8/10
#  32/100 [========>.....................] - ETA: 0s - loss: 0.2220 - recall_21: 0.734100/100 [==============================] - 0s 698us/sample - loss: 0.1549 - recall_21: 0.7750 - val_loss: 0.0971 - val_recall_21: 0.8500
# Epoch 9/10
#  32/100 [========>.....................] - ETA: 0s - loss: 0.1257 - recall_21: 0.828100/100 [==============================] - 0s 689us/sample - loss: 0.1497 - recall_21: 0.8100 - val_loss: 0.1272 - val_recall_21: 0.8500
# Epoch 10/10
#  32/100 [========>.....................] - ETA: 0s - loss: 0.1382 - recall_21: 0.812100/100 [==============================] - 0s 529us/sample - loss: 0.2275 - recall_21: 0.7650 - val_loss: 0.0932 - val_recall_21: 0.8600

# %%
thresholds = [0.6, 0.7, 0.9]
metrics_objs_list=[metrics.Recall(thresholds=thr) for thr in thresholds]

model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=1e-2),
    loss='categorical_crossentropy',
    metrics=metrics_objs_list)

model.fit(X_train, y_train, epochs=10, validation_data=(X_test, y_test))
# Out:
# Train on 100 samples, validate on 50 samples
# Epoch 1/10
#  32/100 [========>.....................] - ETA: 1s - loss: 0.2053 - recall_26: 0.9062 - recall_27: 0.8750 - recall_28: 0.750100/100 [==============================] - 1s 13ms/sample - loss: 0.2463 - recall_26: 0.8500 - recall_27: 0.8100 - recall_28: 0.6900 - val_loss: 0.1210 - val_recall_26: 0.9400 - val_recall_27: 0.8800 - val_recall_28: 0.7800
# Epoch 2/10
#  32/100 [========>.....................] - ETA: 0s - loss: 0.1802 - recall_26: 0.8750 - recall_27: 0.8125 - recall_28: 0.718100/100 [==============================] - 0s 552us/sample - loss: 0.1727 - recall_26: 0.9000 - recall_27: 0.8800 - recall_28: 0.7500 - val_loss: 0.1155 - val_recall_26: 0.9200 - val_recall_27: 0.8800 - val_recall_28: 0.8200
# Epoch 3/10
#  32/100 [========>.....................] - ETA: 0s - loss: 0.1004 - recall_26: 0.9688 - recall_27: 0.9375 - recall_28: 0.687100/100 [==============================] - 0s 572us/sample - loss: 0.1210 - recall_26: 0.9400 - recall_27: 0.8900 - recall_28: 0.7100 - val_loss: 0.0800 - val_recall_26: 0.9600 - val_recall_27: 0.9000 - val_recall_28: 0.8200
# Epoch 4/10
#  32/100 [========>.....................] - ETA: 0s - loss: 0.1271 - recall_26: 0.9375 - recall_27: 0.9062 - recall_28: 0.812100/100 [==============================] - 0s 569us/sample - loss: 0.0915 - recall_26: 0.9700 - recall_27: 0.9400 - recall_28: 0.7900 - val_loss: 0.0732 - val_recall_26: 0.9800 - val_recall_27: 0.9800 - val_recall_28: 0.8000
# Epoch 5/10
#  32/100 [========>.....................] - ETA: 0s - loss: 0.0629 - recall_26: 1.0000 - recall_27: 1.0000 - recall_28: 0.750100/100 [==============================] - 0s 785us/sample - loss: 0.1222 - recall_26: 0.9400 - recall_27: 0.9400 - recall_28: 0.8100 - val_loss: 0.0974 - val_recall_26: 0.9200 - val_recall_27: 0.9000 - val_recall_28: 0.8600
# Epoch 6/10
#  32/100 [========>.....................] - ETA: 0s - loss: 0.0607 - recall_26: 0.9688 - recall_27: 0.9375 - recall_28: 0.906100/100 [==============================] - 0s 553us/sample - loss: 0.1265 - recall_26: 0.9100 - recall_27: 0.8900 - recall_28: 0.7700 - val_loss: 0.0786 - val_recall_26: 0.9200 - val_recall_27: 0.9000 - val_recall_28: 0.8600
# Epoch 7/10
#  32/100 [========>.....................] - ETA: 0s - loss: 0.0809 - recall_26: 0.9375 - recall_27: 0.9375 - recall_28: 0.812100/100 [==============================] - 0s 566us/sample - loss: 0.1103 - recall_26: 0.9400 - recall_27: 0.9200 - recall_28: 0.8000 - val_loss: 0.0608 - val_recall_26: 0.9800 - val_recall_27: 0.9600 - val_recall_28: 0.8600
# Epoch 8/10
#  32/100 [========>.....................] - ETA: 0s - loss: 0.0378 - recall_26: 0.9688 - recall_27: 0.9688 - recall_28: 0.937100/100 [==============================] - 0s 610us/sample - loss: 0.0887 - recall_26: 0.9500 - recall_27: 0.9400 - recall_28: 0.8600 - val_loss: 0.1392 - val_recall_26: 0.9200 - val_recall_27: 0.8800 - val_recall_28: 0.8200
# Epoch 9/10
#  32/100 [========>.....................] - ETA: 0s - loss: 0.1113 - recall_26: 0.9375 - recall_27: 0.8750 - recall_28: 0.812100/100 [==============================] - 0s 813us/sample - loss: 0.0861 - recall_26: 0.9500 - recall_27: 0.9300 - recall_28: 0.8400 - val_loss: 0.0567 - val_recall_26: 0.9800 - val_recall_27: 0.9600 - val_recall_28: 0.8600
# Epoch 10/10
#  32/100 [========>.....................] - ETA: 0s - loss: 0.0768 - recall_26: 0.9688 - recall_27: 0.9688 - recall_28: 0.875100/100 [==============================] - 0s 593us/sample - loss: 0.1088 - recall_26: 0.9500 - recall_27: 0.9400 - recall_28: 0.8500 - val_loss: 0.0548 - val_recall_26: 0.9800 - val_recall_27: 0.9600 - val_recall_28: 0.8600

# %%
model.compile(
    optimizer=keras.optimizers.Adam(learning_rate=1e-2),
    loss='categorical_crossentropy',
    metrics=[metrics.Recall(thresholds=0.6), 
             metrics.Recall(thresholds=0.9)])

model.fit(X_train, y_train, epochs=10, validation_data=(X_test, y_test))
# Out:
# Train on 100 samples, validate on 50 samples
# Epoch 1/10
#  32/100 [========>.....................] - ETA: 1s - loss: 0.0800 - recall_24: 0.9688 - recall_25: 0.750100/100 [==============================] - 1s 10ms/sample - loss: 0.3633 - recall_24: 0.8200 - recall_25: 0.7000 - val_loss: 1.2486 - val_recall_24: 0.6800 - val_recall_25: 0.6800
# Epoch 2/10
#  32/100 [========>.....................] - ETA: 0s - loss: 1.4941 - recall_24: 0.5938 - recall_25: 0.593100/100 [==============================] - 0s 627us/sample - loss: 0.9275 - recall_24: 0.6900 - recall_25: 0.6500 - val_loss: 0.0985 - val_recall_24: 0.9800 - val_recall_25: 0.7400
# Epoch 3/10
#  32/100 [========>.....................] - ETA: 0s - loss: 0.0703 - recall_24: 0.9688 - recall_25: 0.906100/100 [==============================] - 0s 619us/sample - loss: 0.4293 - recall_24: 0.8000 - recall_25: 0.7400 - val_loss: 0.4129 - val_recall_24: 0.7600 - val_recall_25: 0.7000
# Epoch 4/10
#  32/100 [========>.....................] - ETA: 0s - loss: 0.5045 - recall_24: 0.7500 - recall_25: 0.718100/100 [==============================] - 0s 562us/sample - loss: 0.3684 - recall_24: 0.7900 - recall_25: 0.6700 - val_loss: 0.1168 - val_recall_24: 0.9200 - val_recall_25: 0.7600
# Epoch 5/10
#  32/100 [========>.....................] - ETA: 0s - loss: 0.0693 - recall_24: 1.0000 - recall_25: 0.718100/100 [==============================] - 0s 545us/sample - loss: 0.2247 - recall_24: 0.8500 - recall_25: 0.6300 - val_loss: 0.3362 - val_recall_24: 0.8000 - val_recall_25: 0.7000
# Epoch 6/10
#  32/100 [========>.....................] - ETA: 0s - loss: 0.4513 - recall_24: 0.6562 - recall_25: 0.468100/100 [==============================] - 0s 570us/sample - loss: 0.2455 - recall_24: 0.8400 - recall_25: 0.6100 - val_loss: 0.0935 - val_recall_24: 0.9600 - val_recall_25: 0.7400
# Epoch 7/10
#  32/100 [========>.....................] - ETA: 0s - loss: 0.1384 - recall_24: 0.9375 - recall_25: 0.781100/100 [==============================] - 0s 525us/sample - loss: 0.1342 - recall_24: 0.9300 - recall_25: 0.7500 - val_loss: 0.1129 - val_recall_24: 0.9400 - val_recall_25: 0.7400
# Epoch 8/10
#  32/100 [========>.....................] - ETA: 0s - loss: 0.1157 - recall_24: 0.9375 - recall_25: 0.718100/100 [==============================] - 0s 580us/sample - loss: 0.1459 - recall_24: 0.9300 - recall_25: 0.7400 - val_loss: 0.1009 - val_recall_24: 0.9000 - val_recall_25: 0.7800
# Epoch 9/10
#  32/100 [========>.....................] - ETA: 0s - loss: 0.0852 - recall_24: 0.9688 - recall_25: 0.781100/100 [==============================] - 0s 440us/sample - loss: 0.1585 - recall_24: 0.9200 - recall_25: 0.7200 - val_loss: 0.1296 - val_recall_24: 0.9200 - val_recall_25: 0.8000
# Epoch 10/10
#  32/100 [========>.....................] - ETA: 0s - loss: 0.1410 - recall_24: 0.9688 - recall_25: 0.562100/100 [==============================] - 0s 596us/sample - loss: 0.1163 - recall_24: 0.9700 - recall_25: 0.7300 - val_loss: 0.1190 - val_recall_24: 0.9400 - val_recall_25: 0.7800

# %%
import os

tuner = RandomSearch(
    build_model,
    objective=kerastuner.Objective("val_recall", direction="max"), #'val_accuracy',
    max_trials=5,
    executions_per_trial=3,
    directory=os.path.normpath('/Users/germancabrera/Documents/GitRepos/DeepLearning_concepts_checks/project/KERAS_TUNER_CHECKS'),
    project_name='iris_data_keras_tuner_test_mac')
# Out:
# INFO:tensorflow:Reloading Oracle from existing project /Users/germancabrera/Documents/GitRepos/DeepLearning_concepts_checks/project/KERAS_TUNER_CHECKS/iris_data_keras_tuner_test_mac/oracle.json
# INFO:tensorflow:Reloading Tuner from /Users/germancabrera/Documents/GitRepos/DeepLearning_concepts_checks/project/KERAS_TUNER_CHECKS/iris_data_keras_tuner_test_mac/tuner0.json

# %%
tuner.search(X_train, y_train,
             epochs=5,
             validation_data=(X_test, y_test)
             #validation_split=0.2,verbose=1)
             )
# Out:
# INFO:tensorflow:Oracle triggered exit

# %%
tuner.results_summary()
# Out:
# <span style="color:#4527A0"><h1 style="font-size:18px">Results summary</h1></span>
# <span style="color:cyan"> |-Results in /Users/germancabrera/Documents/GitRepos/DeepLearning_concepts_checks/project/KERAS_TUNER_CHECKS/iris_data_keras_tuner_test_mac</span>
# <span style="color:cyan"> |-Showing 10 best trials</span>
# <span style="color:cyan"> |-Objective(name='val_recall', direction='max')</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:cyan"> |-Trial ID: cc0c93f8de49cba3c7b2f973ef5d0990</span>
# <span style="color:cyan"> |-Score: 0.9266666769981384</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hyperparameters:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.01</span>
# <span style="color:blue"> |-units: 384</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:cyan"> |-Trial ID: 2dfa891203b9f5af24a99a739ffb4ae5</span>
# <span style="color:cyan"> |-Score: 0.8733332753181458</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hyperparameters:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.01</span>
# <span style="color:blue"> |-units: 224</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:cyan"> |-Trial ID: df072fd4ddc59bf6839fd871b03e455b</span>
# <span style="color:cyan"> |-Score: 0.4399999678134918</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hyperparameters:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.001</span>
# <span style="color:blue"> |-units: 32</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:cyan"> |-Trial ID: ab2d9901d90bd8c5c0dee8f78db75e3e</span>
# <span style="color:cyan"> |-Score: 0.3333333432674408</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hyperparameters:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.0001</span>
# <span style="color:blue"> |-units: 480</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:cyan"> |-Trial ID: 1432eeecec3b7ac89f25ff938507e012</span>
# <span style="color:cyan"> |-Score: 0.3266666829586029</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hyperparameters:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.0001</span>
# <span style="color:blue"> |-units: 192</span>

# %%
tuner.results_summary()
# Out:
# <span style="color:#4527A0"><h1 style="font-size:18px">Results summary</h1></span>
# <span style="color:cyan"> |-Results in /Users/germancabrera/Documents/GitRepos/DeepLearning_concepts_checks/project/KERAS_TUNER_CHECKS/iris_data_keras_tuner_test_mac</span>
# <span style="color:cyan"> |-Showing 10 best trials</span>
# <span style="color:cyan"> |-Objective(name='val_recall', direction='max')</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:cyan"> |-Trial ID: cc0c93f8de49cba3c7b2f973ef5d0990</span>
# <span style="color:cyan"> |-Score: 0.9266666769981384</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hyperparameters:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.01</span>
# <span style="color:blue"> |-units: 384</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:cyan"> |-Trial ID: 2dfa891203b9f5af24a99a739ffb4ae5</span>
# <span style="color:cyan"> |-Score: 0.8733332753181458</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hyperparameters:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.01</span>
# <span style="color:blue"> |-units: 224</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:cyan"> |-Trial ID: df072fd4ddc59bf6839fd871b03e455b</span>
# <span style="color:cyan"> |-Score: 0.4399999678134918</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hyperparameters:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.001</span>
# <span style="color:blue"> |-units: 32</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:cyan"> |-Trial ID: ab2d9901d90bd8c5c0dee8f78db75e3e</span>
# <span style="color:cyan"> |-Score: 0.3333333432674408</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hyperparameters:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.0001</span>
# <span style="color:blue"> |-units: 480</span>
# <span style="color:#4527A0"><h1 style="font-size:18px">Trial summary</h1></span>
# <span style="color:cyan"> |-Trial ID: 1432eeecec3b7ac89f25ff938507e012</span>
# <span style="color:cyan"> |-Score: 0.3266666829586029</span>
# <span style="color:cyan"> |-Best step: 0</span>
# <span style="color:#7E57C2"><h2 style="font-size:16px">Hyperparameters:</h2></span>
# <span style="color:cyan"> |-learning_rate: 0.0001</span>
# <span style="color:blue"> |-units: 192</span>

# %%
m = metrics.Recall()
m.reset_states()
m.update_state([0, 1, 1, 1], [1, 0, 1, 1]) #, sample_weight=[0, 0, 1, 0])
m.result().numpy()
# Out:
# 0.6666667

# %%
recall_a_mano = 2/3
recall_a_mano
# Out:
# 0.6666666666666666

# %%
# ahora espero obtener el mismo valor usando el default threshold de 0.5
m = metrics.Recall()
m.reset_states()
m.update_state([0, 1, 1, 1], [1, 0.3, 0.8, 0.9]) #, sample_weight=[0, 0, 1, 0])
m.result().numpy()
# Out:
# 0.6666667

# %%
# ahora con threshold de 0.8 obtendré menor recall con las mismas predicciones
m = metrics.Recall(thresholds=0.85)
m.reset_states()
m.update_state([0, 1, 1, 1], [1, 0.3, 0.8, 0.9]) #, sample_weight=[0, 0, 1, 0])
m.result().numpy()
# Out:
# 0.33333334

# %%
m = metrics.Recall(thresholds=[0.6, 0.85])
m.reset_states()
m.update_state([0, 1, 1, 1], [1, 0.3, 0.7, 0.9]) #, sample_weight=[0, 0, 1, 0])
m.result().numpy()
# Out:
# array([0.6666667 , 0.33333334], dtype=float32)

# %% [markdown]
# cuadra al haber acertado un único true positive

# %% [markdown]
# ### Y con el train set?

# %%
categ_acc_train_set = tensorflow.keras.metrics.CategoricalAccuracy()

train_set_predictions = models[0].predict(X_train)
_ = categ_acc_train_set.update_state(y_train, train_set_predictions)
print('best_model_0_train_set_acc: {}'.format(categ_acc_train_set.result().numpy()))
# Out:
# best_model_0_train_set_acc: 0.949999988079071

# %% [markdown]
# ### Obtengo resultado de accuracy mejor que el 0.90 esperado, pruebo si al menos el mejor modelo es el [0]

# %%
import tensorflow

models = tuner.get_best_models(num_models=5)

test_set_predictions_0 = models[0].predict(X_test)
test_set_predictions_1 = models[1].predict(X_test)
test_set_predictions_2 = models[2].predict(X_test)
test_set_predictions_3 = models[3].predict(X_test)
test_set_predictions_4 = models[4].predict(X_test)

# %%
categ_acc_test_set = tensorflow.keras.metrics.CategoricalAccuracy()

#best_model_0_eval_set_acc = tensorflow.keras.metrics.CategoricalAccuracy(y_test.reshape(-1,3), test_set_predictions.reshape(-1,3))
_ = categ_acc_test_set.update_state(y_test, test_set_predictions_0)
print('best_model_0_eval_set_acc: {}'.format(categ_acc_test_set.result().numpy()))

_ = categ_acc_test_set.update_state(y_test, test_set_predictions_1)
print('best_model_0_eval_set_acc: {}'.format(categ_acc_test_set.result().numpy()))

_ = categ_acc_test_set.update_state(y_test, test_set_predictions_2)
print('best_model_0_eval_set_acc: {}'.format(categ_acc_test_set.result().numpy()))

_ = categ_acc_test_set.update_state(y_test, test_set_predictions_3)
print('best_model_0_eval_set_acc: {}'.format(categ_acc_test_set.result().numpy()))

_ = categ_acc_test_set.update_state(y_test, test_set_predictions_4)
print('best_model_0_eval_set_acc: {}'.format(categ_acc_test_set.result().numpy()))
# Out:
# best_model_0_eval_set_acc: 1.0
# best_model_0_eval_set_acc: 0.8600000143051147
# best_model_0_eval_set_acc: 0.800000011920929
# best_model_0_eval_set_acc: 0.7699999809265137
# best_model_0_eval_set_acc: 0.6759999990463257

# %%
models = tuner.get_best_models(num_models=1)
test_set_predictions_0 = models[0].predict(X_test)
categ_acc_test_set = tensorflow.keras.metrics.CategoricalAccuracy()
_ = categ_acc_test_set.update_state(y_test, test_set_predictions_0)
print('best_model_0_eval_set_acc: {}'.format(categ_acc_test_set.result().numpy()))
# Out:
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.iter
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_1
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.beta_2
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.decay
# WARNING:tensorflow:Unresolved object in checkpoint: (root).optimizer.learning_rate
# WARNING:tensorflow:A checkpoint was restored (e.g. tf.train.Checkpoint.restore or tf.keras.Model.load_weights) but not all checkpointed values were used. See above for specific issues. Use expect_partial() on the load status object, e.g. tf.train.Checkpoint.restore(...).expect_partial(), to silence these warnings, or use assert_consumed() to make the check explicit. See https://www.tensorflow.org/guide/checkpoint#loading_mechanics for details.
# best_model_0_eval_set_acc: 1.0

# %% [markdown]
# ## Hasta aquí hemos podido utilizar un RANDOM_SEARCH hiperparametrizador keras tuner
# ### ToDo: acceder a los pesos y arquitectura del modelo
